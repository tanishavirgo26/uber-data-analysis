# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\Tanisha\Desktop\COVID_Data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0      Country        Date  Confirmed  Death  newConfirmed  \
# 0           1  Afghanistan  2019-12-31          0      0             0
# 1           2  Afghanistan  2020-01-01          0      0             0
# 2           3  Afghanistan  2020-01-02          0      0             0
# 3           4  Afghanistan  2020-01-03          0      0             0
# 4           5  Afghanistan  2020-01-04          0      0             0
#
#    newDeath
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Date', 'Confirmed', 'Death', 'newConfirmed',
#        'newDeath'],
#       dtype='object')

# %%
data.describe()
# Out:
#           Unnamed: 0     Confirmed          Death  newConfirmed      newDeath
# count   27550.000000  2.755000e+04   27550.000000  27550.000000  27550.000000
# mean    26583.682686  1.273659e+04     790.741198    308.127586     16.478475
# std     35408.446745  8.421336e+04    5387.391515   1852.325345    111.893189
# min         1.000000  0.000000e+00       0.000000 -10034.000000  -1918.000000
# 25%      6888.250000  0.000000e+00       0.000000      0.000000      0.000000
# 50%     15618.500000  7.400000e+01       1.000000      1.000000      0.000000
# 75%     26326.750000  1.512750e+03      32.000000     41.000000      1.000000
# max    280010.000000  2.191052e+06  118434.000000  36291.000000   2620.000000

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      0
# Country         0
# Date            0
# Confirmed       0
# Death           0
# newConfirmed    0
# newDeath        0
# dtype: int64

# %% [raw]
# # realting the variables with scatterplots

# %%
sns.relplot(x="newDeath",y="newConfirmed",hue="Country",data=data)

# %%
sns.pairplot(data)

# %%
sns.relplot(x="Date",y="newDeath",kind="line",data=data)

# %%
sns.catplot(x="Confirmed",y="Death",data=data)

# %%
sns.catplot(x="Confirmed",y="Death",data=data)

# %%
data.columns
